# %%
import os
from torchvision import transforms, datasets, models
from torch.utils.data import DataLoader
import torch.nn as nn
import torch
from torch import optim
from timeit import default_timer
import numpy as np
import pandas as pd

# %%
data_path = '../chest_xray'         ## chemin vers le dossier contenant les données
train_path = data_path + '/train/'  ## chemin des données d'entrainement
val_path = data_path + '/val/'      ## chemin des données de validation
test_path = data_path + '/test/'    ## chemin des données de tes

save_path = 'model.pth'

# %%
image_transforms = {
    'train':
    transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),     ## changement des différentes transformations pour l'augmentation de données
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),  
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'val':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
  
    'test':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
data = {
    'train':
    datasets.ImageFolder(root=train_path, transform=image_transforms['train']),
    'val':
    datasets.ImageFolder(root=val_path, transform=image_transforms['val']),
    'test':
    datasets.ImageFolder(root=test_path, transform=image_transforms['test'])
}

# %%
batch_size = 128    ## choix de la taille des batchs

dataloaders = {
    'train': DataLoader(data['train'], batch_size=batch_size, shuffle=True),
    'val': DataLoader(data['val'], batch_size=batch_size, shuffle=True),
    'test': DataLoader(data['test'], batch_size=batch_size, shuffle=True)
}

# %%
trainiter = iter(dataloaders['train'])
features, labels = next(trainiter)

# %%
model = models.vgg16(pretrained=True)  ## choix du modèle pré-entrainé

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
n_inputs = model.classifier[6].in_features

model.classifier[6] = nn.Sequential(
    nn.Linear(n_inputs, 2), nn.LogSoftmax(dim=1))  ## choix de remplacement de la dernière couche permettant la classification de 2 classes
 
model = model.to('cuda')

# %%
criterion = nn.NLLLoss()                                  ## choix de la fonction de perte
optimizer = optim.Adam(model.parameters(), lr = 0.05)     ## choix de l'algorithme d'optimisation de la descente de gradient

# %%
nb_epochs = 10          ## choix du nombre d'epochs
history = []

for epoch in range(nb_epochs) :
    start = default_timer()

    
    train_loss = 0.0
    valid_loss = 0.0
    train_acc = 0
    valid_acc = 0

    valid_loss_min = 1000000

    model.train()
    for ii, (data, target) in enumerate(dataloaders['train']):
        data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * data.size(0)
        pred = torch.max(output, dim=1)[1]
        correct_tensor = pred.eq(target.data.view_as(pred))
        correct = np.squeeze(correct_tensor.cpu().numpy())
        accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))
        train_acc += accuracy.item() * data.size(0)
        print(f'Epoch: {epoch}\t{100 * (ii + 1) / len(dataloaders["train"]):.2f}% complete. {default_timer() - start:.2f} seconds elapsed in epoch.')
    with torch.no_grad() :
        model.eval()
        for data, target in dataloaders['val'] :
            data, target = data.cuda(), target.cuda()
            output = model(data)
            loss = criterion(output, target)
            valid_loss += loss.item() * data.size(0)
            pred = torch.max(output, dim=1)[1]
            correct_tensor = pred.eq(target.data.view_as(pred))
            accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))
            valid_acc += accuracy.item() * data.size(0)
        train_loss = train_loss / len(dataloaders['train'].dataset)
        valid_loss = valid_loss / len(dataloaders['val'].dataset)
        train_acc = train_acc / len(dataloaders['train'].dataset)
        valid_acc = valid_acc / len(dataloaders['val'].dataset)
        history.append([train_loss, valid_loss, train_acc, valid_acc])
        if valid_loss < valid_loss_min:
                    torch.save(model.state_dict(), save_path)
                    valid_loss_min = valid_loss
                    valid_best_acc = valid_acc
                    best_epoch = epoch
model.optimizer = optimizer
history = pd.DataFrame(history, columns=['train_loss', 'valid_loss', 'train_acc', 'valid_acc'])


print(history)
# Out:
# Epoch: 0	2.44% complete. 3.06 seconds elapsed in epoch.
# Epoch: 0	4.88% complete. 5.85 seconds elapsed in epoch.
# Epoch: 0	7.32% complete. 8.61 seconds elapsed in epoch.
# Epoch: 0	9.76% complete. 11.59 seconds elapsed in epoch.
# Epoch: 0	12.20% complete. 14.88 seconds elapsed in epoch.
# Epoch: 0	14.63% complete. 17.72 seconds elapsed in epoch.
# Epoch: 0	17.07% complete. 20.76 seconds elapsed in epoch.
# Epoch: 0	19.51% complete. 23.75 seconds elapsed in epoch.
# Epoch: 0	21.95% complete. 26.92 seconds elapsed in epoch.
# Epoch: 0	24.39% complete. 30.19 seconds elapsed in epoch.
# Epoch: 0	26.83% complete. 33.09 seconds elapsed in epoch.
# Epoch: 0	29.27% complete. 35.87 seconds elapsed in epoch.
# Epoch: 0	31.71% complete. 38.81 seconds elapsed in epoch.
# Epoch: 0	34.15% complete. 41.86 seconds elapsed in epoch.
# Epoch: 0	36.59% complete. 44.92 seconds elapsed in epoch.
# Epoch: 0	39.02% complete. 48.10 seconds elapsed in epoch.
# Epoch: 0	41.46% complete. 51.26 seconds elapsed in epoch.
# Epoch: 0	43.90% complete. 54.18 seconds elapsed in epoch.
# Epoch: 0	46.34% complete. 57.30 seconds elapsed in epoch.
# Epoch: 0	48.78% complete. 60.21 seconds elapsed in epoch.
# Epoch: 0	51.22% complete. 63.25 seconds elapsed in epoch.
# Epoch: 0	53.66% complete. 66.29 seconds elapsed in epoch.
# Epoch: 0	56.10% complete. 69.12 seconds elapsed in epoch.
# Epoch: 0	58.54% complete. 72.01 seconds elapsed in epoch.
# Epoch: 0	60.98% complete. 74.85 seconds elapsed in epoch.
# Epoch: 0	63.41% complete. 78.25 seconds elapsed in epoch.
# Epoch: 0	65.85% complete. 81.26 seconds elapsed in epoch.
# Epoch: 0	68.29% complete. 84.24 seconds elapsed in epoch.
# Epoch: 0	70.73% complete. 87.36 seconds elapsed in epoch.
# Epoch: 0	73.17% complete. 90.36 seconds elapsed in epoch.
# Epoch: 0	75.61% complete. 93.39 seconds elapsed in epoch.
# Epoch: 0	78.05% complete. 96.54 seconds elapsed in epoch.
# Epoch: 0	80.49% complete. 99.68 seconds elapsed in epoch.
# Epoch: 0	82.93% complete. 102.69 seconds elapsed in epoch.
# Epoch: 0	85.37% complete. 105.57 seconds elapsed in epoch.
# Epoch: 0	87.80% complete. 108.67 seconds elapsed in epoch.
# Epoch: 0	90.24% complete. 111.68 seconds elapsed in epoch.
# Epoch: 0	92.68% complete. 114.67 seconds elapsed in epoch.
# Epoch: 0	95.12% complete. 117.73 seconds elapsed in epoch.
# Epoch: 0	97.56% complete. 120.94 seconds elapsed in epoch.
# Epoch: 0	100.00% complete. 123.30 seconds elapsed in epoch.
# Epoch: 1	2.44% complete. 3.17 seconds elapsed in epoch.
# Epoch: 1	4.88% complete. 6.29 seconds elapsed in epoch.
# Epoch: 1	7.32% complete. 9.37 seconds elapsed in epoch.
# Epoch: 1	9.76% complete. 12.30 seconds elapsed in epoch.
# Epoch: 1	12.20% complete. 15.33 seconds elapsed in epoch.
# Epoch: 1	14.63% complete. 18.48 seconds elapsed in epoch.
# Epoch: 1	17.07% complete. 21.61 seconds elapsed in epoch.
# Epoch: 1	19.51% complete. 24.62 seconds elapsed in epoch.
# Epoch: 1	21.95% complete. 27.42 seconds elapsed in epoch.
# Epoch: 1	24.39% complete. 30.38 seconds elapsed in epoch.
# Epoch: 1	26.83% complete. 33.62 seconds elapsed in epoch.
# Epoch: 1	29.27% complete. 36.83 seconds elapsed in epoch.
# Epoch: 1	31.71% complete. 39.84 seconds elapsed in epoch.
# Epoch: 1	34.15% complete. 42.90 seconds elapsed in epoch.
# Epoch: 1	36.59% complete. 45.77 seconds elapsed in epoch.
# Epoch: 1	39.02% complete. 49.00 seconds elapsed in epoch.
# Epoch: 1	41.46% complete. 51.76 seconds elapsed in epoch.
# Epoch: 1	43.90% complete. 54.96 seconds elapsed in epoch.
# Epoch: 1	46.34% complete. 57.74 seconds elapsed in epoch.
# Epoch: 1	48.78% complete. 60.57 seconds elapsed in epoch.
# Epoch: 1	51.22% complete. 63.80 seconds elapsed in epoch.
# Epoch: 1	53.66% complete. 66.75 seconds elapsed in epoch.
# Epoch: 1	56.10% complete. 69.98 seconds elapsed in epoch.
# Epoch: 1	58.54% complete. 73.05 seconds elapsed in epoch.
# Epoch: 1	60.98% complete. 75.96 seconds elapsed in epoch.
# Epoch: 1	63.41% complete. 78.74 seconds elapsed in epoch.
# Epoch: 1	65.85% complete. 81.91 seconds elapsed in epoch.
# Epoch: 1	68.29% complete. 84.72 seconds elapsed in epoch.
# Epoch: 1	70.73% complete. 87.72 seconds elapsed in epoch.
# Epoch: 1	73.17% complete. 90.98 seconds elapsed in epoch.
# Epoch: 1	75.61% complete. 93.91 seconds elapsed in epoch.
# Epoch: 1	78.05% complete. 97.01 seconds elapsed in epoch.
# Epoch: 1	80.49% complete. 99.96 seconds elapsed in epoch.
# Epoch: 1	82.93% complete. 102.85 seconds elapsed in epoch.
# Epoch: 1	85.37% complete. 105.90 seconds elapsed in epoch.
# Epoch: 1	87.80% complete. 108.85 seconds elapsed in epoch.
# Epoch: 1	90.24% complete. 111.93 seconds elapsed in epoch.
# Epoch: 1	92.68% complete. 115.16 seconds elapsed in epoch.
# Epoch: 1	95.12% complete. 118.04 seconds elapsed in epoch.
# Epoch: 1	97.56% complete. 120.99 seconds elapsed in epoch.
# Epoch: 1	100.00% complete. 123.47 seconds elapsed in epoch.
# Epoch: 2	2.44% complete. 2.99 seconds elapsed in epoch.
# Epoch: 2	4.88% complete. 6.04 seconds elapsed in epoch.
# Epoch: 2	7.32% complete. 8.75 seconds elapsed in epoch.
# Epoch: 2	9.76% complete. 11.70 seconds elapsed in epoch.
# Epoch: 2	12.20% complete. 14.76 seconds elapsed in epoch.
# Epoch: 2	14.63% complete. 17.73 seconds elapsed in epoch.
# Epoch: 2	17.07% complete. 20.94 seconds elapsed in epoch.
# Epoch: 2	19.51% complete. 23.79 seconds elapsed in epoch.
# Epoch: 2	21.95% complete. 27.04 seconds elapsed in epoch.
# Epoch: 2	24.39% complete. 30.11 seconds elapsed in epoch.
# Epoch: 2	26.83% complete. 33.10 seconds elapsed in epoch.
# Epoch: 2	29.27% complete. 36.17 seconds elapsed in epoch.
# Epoch: 2	31.71% complete. 39.12 seconds elapsed in epoch.
# Epoch: 2	34.15% complete. 42.14 seconds elapsed in epoch.
# Epoch: 2	36.59% complete. 45.15 seconds elapsed in epoch.
# Epoch: 2	39.02% complete. 47.87 seconds elapsed in epoch.
# Epoch: 2	41.46% complete. 50.84 seconds elapsed in epoch.
# Epoch: 2	43.90% complete. 53.91 seconds elapsed in epoch.
# Epoch: 2	46.34% complete. 56.80 seconds elapsed in epoch.
# Epoch: 2	48.78% complete. 59.88 seconds elapsed in epoch.
# Epoch: 2	51.22% complete. 62.90 seconds elapsed in epoch.
# Epoch: 2	53.66% complete. 66.06 seconds elapsed in epoch.
# Epoch: 2	56.10% complete. 69.11 seconds elapsed in epoch.
# Epoch: 2	58.54% complete. 72.20 seconds elapsed in epoch.
# Epoch: 2	60.98% complete. 75.27 seconds elapsed in epoch.
# Epoch: 2	63.41% complete. 78.23 seconds elapsed in epoch.
# Epoch: 2	65.85% complete. 81.21 seconds elapsed in epoch.
# Epoch: 2	68.29% complete. 84.18 seconds elapsed in epoch.
# Epoch: 2	70.73% complete. 87.22 seconds elapsed in epoch.
# Epoch: 2	73.17% complete. 90.14 seconds elapsed in epoch.
# Epoch: 2	75.61% complete. 93.29 seconds elapsed in epoch.
# Epoch: 2	78.05% complete. 96.27 seconds elapsed in epoch.
# Epoch: 2	80.49% complete. 99.24 seconds elapsed in epoch.
# Epoch: 2	82.93% complete. 102.05 seconds elapsed in epoch.
# Epoch: 2	85.37% complete. 105.22 seconds elapsed in epoch.
# Epoch: 2	87.80% complete. 108.20 seconds elapsed in epoch.
# Epoch: 2	90.24% complete. 111.36 seconds elapsed in epoch.
# Epoch: 2	92.68% complete. 114.28 seconds elapsed in epoch.
# Epoch: 2	95.12% complete. 117.41 seconds elapsed in epoch.
# Epoch: 2	97.56% complete. 120.75 seconds elapsed in epoch.
# Epoch: 2	100.00% complete. 123.00 seconds elapsed in epoch.
# Epoch: 3	2.44% complete. 2.92 seconds elapsed in epoch.
# Epoch: 3	4.88% complete. 6.08 seconds elapsed in epoch.
# Epoch: 3	7.32% complete. 9.15 seconds elapsed in epoch.
# Epoch: 3	9.76% complete. 12.38 seconds elapsed in epoch.
# Epoch: 3	12.20% complete. 15.38 seconds elapsed in epoch.
# Epoch: 3	14.63% complete. 18.44 seconds elapsed in epoch.
# Epoch: 3	17.07% complete. 21.63 seconds elapsed in epoch.
# Epoch: 3	19.51% complete. 24.62 seconds elapsed in epoch.
# Epoch: 3	21.95% complete. 27.74 seconds elapsed in epoch.
# Epoch: 3	24.39% complete. 30.91 seconds elapsed in epoch.
# Epoch: 3	26.83% complete. 33.98 seconds elapsed in epoch.
# Epoch: 3	29.27% complete. 36.93 seconds elapsed in epoch.
# Epoch: 3	31.71% complete. 39.91 seconds elapsed in epoch.
# Epoch: 3	34.15% complete. 42.80 seconds elapsed in epoch.
# Epoch: 3	36.59% complete. 45.96 seconds elapsed in epoch.
# Epoch: 3	39.02% complete. 49.08 seconds elapsed in epoch.
# Epoch: 3	41.46% complete. 52.22 seconds elapsed in epoch.
# Epoch: 3	43.90% complete. 55.05 seconds elapsed in epoch.
# Epoch: 3	46.34% complete. 58.15 seconds elapsed in epoch.
# Epoch: 3	48.78% complete. 61.09 seconds elapsed in epoch.
# Epoch: 3	51.22% complete. 64.29 seconds elapsed in epoch.
# Epoch: 3	53.66% complete. 67.24 seconds elapsed in epoch.
# Epoch: 3	56.10% complete. 70.22 seconds elapsed in epoch.
# Epoch: 3	58.54% complete. 73.06 seconds elapsed in epoch.
# Epoch: 3	60.98% complete. 76.08 seconds elapsed in epoch.
# Epoch: 3	63.41% complete. 79.17 seconds elapsed in epoch.
# Epoch: 3	65.85% complete. 82.28 seconds elapsed in epoch.
# Epoch: 3	68.29% complete. 85.05 seconds elapsed in epoch.
# Epoch: 3	70.73% complete. 88.09 seconds elapsed in epoch.
# Epoch: 3	73.17% complete. 91.07 seconds elapsed in epoch.
# Epoch: 3	75.61% complete. 94.21 seconds elapsed in epoch.
# Epoch: 3	78.05% complete. 97.14 seconds elapsed in epoch.
# Epoch: 3	80.49% complete. 100.00 seconds elapsed in epoch.
# Epoch: 3	82.93% complete. 103.17 seconds elapsed in epoch.
# Epoch: 3	85.37% complete. 106.04 seconds elapsed in epoch.
# Epoch: 3	87.80% complete. 109.13 seconds elapsed in epoch.
# Epoch: 3	90.24% complete. 112.32 seconds elapsed in epoch.
# Epoch: 3	92.68% complete. 115.23 seconds elapsed in epoch.
# Epoch: 3	95.12% complete. 118.14 seconds elapsed in epoch.
# Epoch: 3	97.56% complete. 121.15 seconds elapsed in epoch.
# Epoch: 3	100.00% complete. 123.41 seconds elapsed in epoch.
# Epoch: 4	2.44% complete. 3.23 seconds elapsed in epoch.
# Epoch: 4	4.88% complete. 6.26 seconds elapsed in epoch.
# Epoch: 4	7.32% complete. 9.53 seconds elapsed in epoch.
# Epoch: 4	9.76% complete. 12.55 seconds elapsed in epoch.
# Epoch: 4	12.20% complete. 15.60 seconds elapsed in epoch.
# Epoch: 4	14.63% complete. 18.64 seconds elapsed in epoch.
# Epoch: 4	17.07% complete. 21.66 seconds elapsed in epoch.
# Epoch: 4	19.51% complete. 24.60 seconds elapsed in epoch.
# Epoch: 4	21.95% complete. 27.49 seconds elapsed in epoch.
# Epoch: 4	24.39% complete. 30.53 seconds elapsed in epoch.
# Epoch: 4	26.83% complete. 33.63 seconds elapsed in epoch.
# Epoch: 4	29.27% complete. 36.59 seconds elapsed in epoch.
# Epoch: 4	31.71% complete. 39.72 seconds elapsed in epoch.
# Epoch: 4	34.15% complete. 43.01 seconds elapsed in epoch.
# Epoch: 4	36.59% complete. 45.95 seconds elapsed in epoch.
# Epoch: 4	39.02% complete. 49.14 seconds elapsed in epoch.
# Epoch: 4	41.46% complete. 52.16 seconds elapsed in epoch.
# Epoch: 4	43.90% complete. 55.45 seconds elapsed in epoch.
# Epoch: 4	46.34% complete. 58.30 seconds elapsed in epoch.
# Epoch: 4	48.78% complete. 61.12 seconds elapsed in epoch.
# Epoch: 4	51.22% complete. 63.96 seconds elapsed in epoch.
# Epoch: 4	53.66% complete. 66.94 seconds elapsed in epoch.
# Epoch: 4	56.10% complete. 69.83 seconds elapsed in epoch.
# Epoch: 4	58.54% complete. 72.83 seconds elapsed in epoch.
# Epoch: 4	60.98% complete. 76.13 seconds elapsed in epoch.
# Epoch: 4	63.41% complete. 79.11 seconds elapsed in epoch.
# Epoch: 4	65.85% complete. 82.07 seconds elapsed in epoch.
# Epoch: 4	68.29% complete. 85.02 seconds elapsed in epoch.
# Epoch: 4	70.73% complete. 87.96 seconds elapsed in epoch.
# Epoch: 4	73.17% complete. 90.98 seconds elapsed in epoch.
# Epoch: 4	75.61% complete. 93.98 seconds elapsed in epoch.
# Epoch: 4	78.05% complete. 96.90 seconds elapsed in epoch.
# Epoch: 4	80.49% complete. 99.97 seconds elapsed in epoch.
# Epoch: 4	82.93% complete. 102.85 seconds elapsed in epoch.
# Epoch: 4	85.37% complete. 105.77 seconds elapsed in epoch.
# Epoch: 4	87.80% complete. 109.02 seconds elapsed in epoch.
# Epoch: 4	90.24% complete. 111.92 seconds elapsed in epoch.
# Epoch: 4	92.68% complete. 114.92 seconds elapsed in epoch.
# Epoch: 4	95.12% complete. 117.88 seconds elapsed in epoch.
# Epoch: 4	97.56% complete. 120.90 seconds elapsed in epoch.
# Epoch: 4	100.00% complete. 123.11 seconds elapsed in epoch.
# Epoch: 5	2.44% complete. 3.00 seconds elapsed in epoch.
# Epoch: 5	4.88% complete. 6.10 seconds elapsed in epoch.
# Epoch: 5	7.32% complete. 9.26 seconds elapsed in epoch.
# Epoch: 5	9.76% complete. 12.21 seconds elapsed in epoch.
# Epoch: 5	12.20% complete. 15.21 seconds elapsed in epoch.
# Epoch: 5	14.63% complete. 18.27 seconds elapsed in epoch.
# Epoch: 5	17.07% complete. 21.15 seconds elapsed in epoch.
# Epoch: 5	19.51% complete. 24.37 seconds elapsed in epoch.
# Epoch: 5	21.95% complete. 27.40 seconds elapsed in epoch.
# Epoch: 5	24.39% complete. 30.38 seconds elapsed in epoch.
# Epoch: 5	26.83% complete. 33.14 seconds elapsed in epoch.
# Epoch: 5	29.27% complete. 36.16 seconds elapsed in epoch.
# Epoch: 5	31.71% complete. 39.19 seconds elapsed in epoch.
# Epoch: 5	34.15% complete. 42.05 seconds elapsed in epoch.
# Epoch: 5	36.59% complete. 45.29 seconds elapsed in epoch.
# Epoch: 5	39.02% complete. 48.25 seconds elapsed in epoch.
# Epoch: 5	41.46% complete. 51.38 seconds elapsed in epoch.
# Epoch: 5	43.90% complete. 54.38 seconds elapsed in epoch.
# Epoch: 5	46.34% complete. 57.36 seconds elapsed in epoch.
# Epoch: 5	48.78% complete. 60.56 seconds elapsed in epoch.
# Epoch: 5	51.22% complete. 63.68 seconds elapsed in epoch.
# Epoch: 5	53.66% complete. 66.49 seconds elapsed in epoch.
# Epoch: 5	56.10% complete. 69.57 seconds elapsed in epoch.
# Epoch: 5	58.54% complete. 72.53 seconds elapsed in epoch.
# Epoch: 5	60.98% complete. 75.49 seconds elapsed in epoch.
# Epoch: 5	63.41% complete. 78.53 seconds elapsed in epoch.
# Epoch: 5	65.85% complete. 81.73 seconds elapsed in epoch.
# Epoch: 5	68.29% complete. 84.81 seconds elapsed in epoch.
# Epoch: 5	70.73% complete. 87.86 seconds elapsed in epoch.
# Epoch: 5	73.17% complete. 90.95 seconds elapsed in epoch.
# Epoch: 5	75.61% complete. 93.98 seconds elapsed in epoch.
# Epoch: 5	78.05% complete. 97.00 seconds elapsed in epoch.
# Epoch: 5	80.49% complete. 100.11 seconds elapsed in epoch.
# Epoch: 5	82.93% complete. 102.87 seconds elapsed in epoch.
# Epoch: 5	85.37% complete. 105.84 seconds elapsed in epoch.
# Epoch: 5	87.80% complete. 108.93 seconds elapsed in epoch.
# Epoch: 5	90.24% complete. 111.75 seconds elapsed in epoch.
# Epoch: 5	92.68% complete. 114.73 seconds elapsed in epoch.
# Epoch: 5	95.12% complete. 118.32 seconds elapsed in epoch.
# Epoch: 5	97.56% complete. 121.16 seconds elapsed in epoch.
# Epoch: 5	100.00% complete. 123.30 seconds elapsed in epoch.
# Epoch: 6	2.44% complete. 3.12 seconds elapsed in epoch.
# Epoch: 6	4.88% complete. 5.98 seconds elapsed in epoch.
# Epoch: 6	7.32% complete. 9.01 seconds elapsed in epoch.
# Epoch: 6	9.76% complete. 12.23 seconds elapsed in epoch.
# Epoch: 6	12.20% complete. 15.24 seconds elapsed in epoch.
# Epoch: 6	14.63% complete. 18.29 seconds elapsed in epoch.
# Epoch: 6	17.07% complete. 21.34 seconds elapsed in epoch.
# Epoch: 6	19.51% complete. 24.30 seconds elapsed in epoch.
# Epoch: 6	21.95% complete. 27.54 seconds elapsed in epoch.
# Epoch: 6	24.39% complete. 30.75 seconds elapsed in epoch.
# Epoch: 6	26.83% complete. 33.61 seconds elapsed in epoch.
# Epoch: 6	29.27% complete. 36.48 seconds elapsed in epoch.
# Epoch: 6	31.71% complete. 39.28 seconds elapsed in epoch.
# Epoch: 6	34.15% complete. 42.26 seconds elapsed in epoch.
# Epoch: 6	36.59% complete. 45.36 seconds elapsed in epoch.
# Epoch: 6	39.02% complete. 48.43 seconds elapsed in epoch.
# Epoch: 6	41.46% complete. 51.49 seconds elapsed in epoch.
# Epoch: 6	43.90% complete. 54.54 seconds elapsed in epoch.
# Epoch: 6	46.34% complete. 57.42 seconds elapsed in epoch.
# Epoch: 6	48.78% complete. 60.38 seconds elapsed in epoch.
# Epoch: 6	51.22% complete. 63.54 seconds elapsed in epoch.
# Epoch: 6	53.66% complete. 66.56 seconds elapsed in epoch.
# Epoch: 6	56.10% complete. 69.89 seconds elapsed in epoch.
# Epoch: 6	58.54% complete. 72.70 seconds elapsed in epoch.
# Epoch: 6	60.98% complete. 75.68 seconds elapsed in epoch.
# Epoch: 6	63.41% complete. 78.51 seconds elapsed in epoch.
# Epoch: 6	65.85% complete. 81.37 seconds elapsed in epoch.
# Epoch: 6	68.29% complete. 84.33 seconds elapsed in epoch.
# Epoch: 6	70.73% complete. 87.56 seconds elapsed in epoch.
# Epoch: 6	73.17% complete. 90.63 seconds elapsed in epoch.
# Epoch: 6	75.61% complete. 93.96 seconds elapsed in epoch.
# Epoch: 6	78.05% complete. 97.07 seconds elapsed in epoch.
# Epoch: 6	80.49% complete. 100.04 seconds elapsed in epoch.
# Epoch: 6	82.93% complete. 102.92 seconds elapsed in epoch.
# Epoch: 6	85.37% complete. 105.89 seconds elapsed in epoch.
# Epoch: 6	87.80% complete. 108.69 seconds elapsed in epoch.
# Epoch: 6	90.24% complete. 111.71 seconds elapsed in epoch.
# Epoch: 6	92.68% complete. 114.78 seconds elapsed in epoch.
# Epoch: 6	95.12% complete. 118.02 seconds elapsed in epoch.
# Epoch: 6	97.56% complete. 120.95 seconds elapsed in epoch.
# Epoch: 6	100.00% complete. 123.37 seconds elapsed in epoch.
# Epoch: 7	2.44% complete. 2.99 seconds elapsed in epoch.
# Epoch: 7	4.88% complete. 5.76 seconds elapsed in epoch.
# Epoch: 7	7.32% complete. 8.80 seconds elapsed in epoch.
# Epoch: 7	9.76% complete. 11.97 seconds elapsed in epoch.
# Epoch: 7	12.20% complete. 14.88 seconds elapsed in epoch.
# Epoch: 7	14.63% complete. 18.08 seconds elapsed in epoch.
# Epoch: 7	17.07% complete. 20.87 seconds elapsed in epoch.
# Epoch: 7	19.51% complete. 24.05 seconds elapsed in epoch.
# Epoch: 7	21.95% complete. 27.03 seconds elapsed in epoch.
# Epoch: 7	24.39% complete. 30.04 seconds elapsed in epoch.
# Epoch: 7	26.83% complete. 33.04 seconds elapsed in epoch.
# Epoch: 7	29.27% complete. 36.13 seconds elapsed in epoch.
# Epoch: 7	31.71% complete. 39.15 seconds elapsed in epoch.
# Epoch: 7	34.15% complete. 42.37 seconds elapsed in epoch.
# Epoch: 7	36.59% complete. 45.42 seconds elapsed in epoch.
# Epoch: 7	39.02% complete. 48.38 seconds elapsed in epoch.
# Epoch: 7	41.46% complete. 51.45 seconds elapsed in epoch.
# Epoch: 7	43.90% complete. 54.60 seconds elapsed in epoch.
# Epoch: 7	46.34% complete. 57.66 seconds elapsed in epoch.
# Epoch: 7	48.78% complete. 60.79 seconds elapsed in epoch.
# Epoch: 7	51.22% complete. 63.77 seconds elapsed in epoch.
# Epoch: 7	53.66% complete. 66.87 seconds elapsed in epoch.
# Epoch: 7	56.10% complete. 69.87 seconds elapsed in epoch.
# Epoch: 7	58.54% complete. 72.77 seconds elapsed in epoch.
# Epoch: 7	60.98% complete. 75.93 seconds elapsed in epoch.
# Epoch: 7	63.41% complete. 78.95 seconds elapsed in epoch.
# Epoch: 7	65.85% complete. 81.90 seconds elapsed in epoch.
# Epoch: 7	68.29% complete. 84.84 seconds elapsed in epoch.
# Epoch: 7	70.73% complete. 87.81 seconds elapsed in epoch.
# Epoch: 7	73.17% complete. 90.81 seconds elapsed in epoch.
# Epoch: 7	75.61% complete. 93.74 seconds elapsed in epoch.
# Epoch: 7	78.05% complete. 96.81 seconds elapsed in epoch.
# Epoch: 7	80.49% complete. 99.86 seconds elapsed in epoch.
# Epoch: 7	82.93% complete. 102.81 seconds elapsed in epoch.
# Epoch: 7	85.37% complete. 105.85 seconds elapsed in epoch.
# Epoch: 7	87.80% complete. 108.78 seconds elapsed in epoch.
# Epoch: 7	90.24% complete. 111.76 seconds elapsed in epoch.
# Epoch: 7	92.68% complete. 114.80 seconds elapsed in epoch.
# Epoch: 7	95.12% complete. 117.67 seconds elapsed in epoch.
# Epoch: 7	97.56% complete. 120.89 seconds elapsed in epoch.
# Epoch: 7	100.00% complete. 123.16 seconds elapsed in epoch.
# Epoch: 8	2.44% complete. 2.93 seconds elapsed in epoch.
# Epoch: 8	4.88% complete. 6.18 seconds elapsed in epoch.
# Epoch: 8	7.32% complete. 9.02 seconds elapsed in epoch.
# Epoch: 8	9.76% complete. 12.29 seconds elapsed in epoch.
# Epoch: 8	12.20% complete. 15.33 seconds elapsed in epoch.
# Epoch: 8	14.63% complete. 18.30 seconds elapsed in epoch.
# Epoch: 8	17.07% complete. 21.05 seconds elapsed in epoch.
# Epoch: 8	19.51% complete. 24.22 seconds elapsed in epoch.
# Epoch: 8	21.95% complete. 27.24 seconds elapsed in epoch.
# Epoch: 8	24.39% complete. 29.98 seconds elapsed in epoch.
# Epoch: 8	26.83% complete. 33.19 seconds elapsed in epoch.
# Epoch: 8	29.27% complete. 36.26 seconds elapsed in epoch.
# Epoch: 8	31.71% complete. 39.20 seconds elapsed in epoch.
# Epoch: 8	34.15% complete. 42.27 seconds elapsed in epoch.
# Epoch: 8	36.59% complete. 45.28 seconds elapsed in epoch.
# Epoch: 8	39.02% complete. 48.62 seconds elapsed in epoch.
# Epoch: 8	41.46% complete. 51.74 seconds elapsed in epoch.
# Epoch: 8	43.90% complete. 54.84 seconds elapsed in epoch.
# Epoch: 8	46.34% complete. 57.88 seconds elapsed in epoch.
# Epoch: 8	48.78% complete. 61.02 seconds elapsed in epoch.
# Epoch: 8	51.22% complete. 63.79 seconds elapsed in epoch.
# Epoch: 8	53.66% complete. 66.96 seconds elapsed in epoch.
# Epoch: 8	56.10% complete. 69.89 seconds elapsed in epoch.
# Epoch: 8	58.54% complete. 72.92 seconds elapsed in epoch.
# Epoch: 8	60.98% complete. 76.10 seconds elapsed in epoch.
# Epoch: 8	63.41% complete. 79.10 seconds elapsed in epoch.
# Epoch: 8	65.85% complete. 82.20 seconds elapsed in epoch.
# Epoch: 8	68.29% complete. 85.16 seconds elapsed in epoch.
# Epoch: 8	70.73% complete. 88.09 seconds elapsed in epoch.
# Epoch: 8	73.17% complete. 91.32 seconds elapsed in epoch.
# Epoch: 8	75.61% complete. 94.27 seconds elapsed in epoch.
# Epoch: 8	78.05% complete. 97.44 seconds elapsed in epoch.
# Epoch: 8	80.49% complete. 100.45 seconds elapsed in epoch.
# Epoch: 8	82.93% complete. 103.39 seconds elapsed in epoch.
# Epoch: 8	85.37% complete. 106.52 seconds elapsed in epoch.
# Epoch: 8	87.80% complete. 109.63 seconds elapsed in epoch.
# Epoch: 8	90.24% complete. 112.49 seconds elapsed in epoch.
# Epoch: 8	92.68% complete. 115.46 seconds elapsed in epoch.
# Epoch: 8	95.12% complete. 118.37 seconds elapsed in epoch.
# Epoch: 8	97.56% complete. 121.38 seconds elapsed in epoch.
# Epoch: 8	100.00% complete. 123.78 seconds elapsed in epoch.
# Epoch: 9	2.44% complete. 3.12 seconds elapsed in epoch.
# Epoch: 9	4.88% complete. 6.14 seconds elapsed in epoch.
# Epoch: 9	7.32% complete. 9.24 seconds elapsed in epoch.
# Epoch: 9	9.76% complete. 12.08 seconds elapsed in epoch.
# Epoch: 9	12.20% complete. 15.21 seconds elapsed in epoch.
# Epoch: 9	14.63% complete. 18.14 seconds elapsed in epoch.
# Epoch: 9	17.07% complete. 21.34 seconds elapsed in epoch.
# Epoch: 9	19.51% complete. 24.32 seconds elapsed in epoch.
# Epoch: 9	21.95% complete. 27.16 seconds elapsed in epoch.
# Epoch: 9	24.39% complete. 30.20 seconds elapsed in epoch.
# Epoch: 9	26.83% complete. 33.34 seconds elapsed in epoch.
# Epoch: 9	29.27% complete. 36.45 seconds elapsed in epoch.
# Epoch: 9	31.71% complete. 39.29 seconds elapsed in epoch.
# Epoch: 9	34.15% complete. 42.45 seconds elapsed in epoch.
# Epoch: 9	36.59% complete. 45.50 seconds elapsed in epoch.
# Epoch: 9	39.02% complete. 48.48 seconds elapsed in epoch.
# Epoch: 9	41.46% complete. 51.71 seconds elapsed in epoch.
# Epoch: 9	43.90% complete. 54.96 seconds elapsed in epoch.
# Epoch: 9	46.34% complete. 57.91 seconds elapsed in epoch.
# Epoch: 9	48.78% complete. 61.00 seconds elapsed in epoch.
# Epoch: 9	51.22% complete. 63.94 seconds elapsed in epoch.
# Epoch: 9	53.66% complete. 67.24 seconds elapsed in epoch.
# Epoch: 9	56.10% complete. 70.10 seconds elapsed in epoch.
# Epoch: 9	58.54% complete. 73.00 seconds elapsed in epoch.
# Epoch: 9	60.98% complete. 75.91 seconds elapsed in epoch.
# Epoch: 9	63.41% complete. 79.05 seconds elapsed in epoch.
# Epoch: 9	65.85% complete. 82.21 seconds elapsed in epoch.
# Epoch: 9	68.29% complete. 84.98 seconds elapsed in epoch.
# Epoch: 9	70.73% complete. 88.12 seconds elapsed in epoch.
# Epoch: 9	73.17% complete. 90.94 seconds elapsed in epoch.
# Epoch: 9	75.61% complete. 93.88 seconds elapsed in epoch.
# Epoch: 9	78.05% complete. 96.67 seconds elapsed in epoch.
# Epoch: 9	80.49% complete. 99.63 seconds elapsed in epoch.
# Epoch: 9	82.93% complete. 102.35 seconds elapsed in epoch.
# Epoch: 9	85.37% complete. 105.50 seconds elapsed in epoch.
# Epoch: 9	87.80% complete. 108.52 seconds elapsed in epoch.
# Epoch: 9	90.24% complete. 111.56 seconds elapsed in epoch.
# Epoch: 9	92.68% complete. 114.50 seconds elapsed in epoch.
# Epoch: 9	95.12% complete. 117.51 seconds elapsed in epoch.
# Epoch: 9	97.56% complete. 120.71 seconds elapsed in epoch.
# Epoch: 9	100.00% complete. 123.10 seconds elapsed in epoch.
#    train_loss  valid_loss  train_acc  valid_acc
# 0    3.692825    0.606389   0.833014     0.9375
# 1    1.379787    0.192642   0.881518     0.9375
# 2    1.179256    0.141529   0.887462     0.9375
# 3    1.401904    0.148940   0.875575     0.9375
# 4    1.498095    0.216952   0.876725     0.8750
# 5    1.584581    0.856753   0.875000     0.8125
# 6    1.636267    0.918896   0.884969     0.8125
# 7    1.840341    0.536244   0.885544     0.8750
# 8    1.847740    1.218070   0.882669     0.8125
# 9    1.748217    0.011964   0.882669     1.0000

# %%
model.load_state_dict(torch.load(save_path))
model.eval()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=2, bias=True)
#       (1): LogSoftmax(dim=1)
#     )
#   )
# )

# %%
test_loader=dataloaders['test']
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))
classes = [0,1]
model.eval()
i = 1
for data, target in test_loader:
    i=i+1
    if len(target)!=batch_size:
        continue
    data, target = data.cuda(), target.cuda()
    output = model(data)
    loss = criterion(output, target)
    test_loss += loss.item()*data.size(0)
    _, pred = torch.max(output, 1)    
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.cpu().numpy())
    
    for i in range(batch_size):       
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

test_loss = test_loss/len(test_loader.dataset)
print('Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Précision de test de %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))

print('\nPrécision de test (Total): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 2.639630
#
# Test Accuracy of     0: 56% (108/191)
# Test Accuracy of     1: 96% (310/321)
#
# Test Accuracy (Overall): 81% (418/512)
